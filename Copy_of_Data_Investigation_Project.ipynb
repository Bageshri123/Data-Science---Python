# %% [markdown]
# <a href="https://colab.research.google.com/github/Bageshri123/Data-Science---Python/blob/main/Copy_of_Data_Investigation_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data investigation project
# ---
#
# Use what you have learnt so far about reading data files and displaying rows, columns, unique values, etc, to investigate and produce some printed information from this data set: https://raw.githubusercontent.com/futureCodersSE/working-with-data/main/Data%20sets/housing_in_london_yearly_variables.csv

# %% [markdown]
# **Display first 20 records from the dataset**

# %%
import pandas as pd
url="https://raw.githubusercontent.com/futureCodersSE/working-with-data/main/Data%20sets/housing_in_london_yearly_variables.csv"
df=pd.read_csv(url)
df.head(20)
# Out:
#          code                    area  ... no_of_houses  borough_flag
# 0   E09000001          city of london  ...          NaN             1
# 1   E09000002    barking and dagenham  ...          NaN             1
# 2   E09000003                  barnet  ...          NaN             1
# 3   E09000004                  bexley  ...          NaN             1
# 4   E09000005                   brent  ...          NaN             1
# 5   E09000006                 bromley  ...          NaN             1
# 6   E09000007                  camden  ...          NaN             1
# 7   E09000008                 croydon  ...          NaN             1
# 8   E09000009                  ealing  ...          NaN             1
# 9   E09000010                 enfield  ...          NaN             1
# 10  E09000011               greenwich  ...          NaN             1
# 11  E09000012                 hackney  ...          NaN             1
# ...

# %% [markdown]
# **Display net population size**

# %%
import pandas as pd
url="https://raw.githubusercontent.com/futureCodersSE/working-with-data/main/Data%20sets/housing_in_london_yearly_variables.csv"
df=pd.read_csv(url)
print("Net population size is:",df['population_size'].sum())
# Out:
# Net population size is: 6151342865.0

# %% [markdown]
# **Dispaly areas with highest and lowest of average salary**

# %%
import pandas as pd

url="https://raw.githubusercontent.com/futureCodersSE/working-with-data/main/Data%20sets/housing_in_london_yearly_variables.csv"
df=pd.read_csv(url)

#to find highest average salary and it's area
highest=df['mean_salary'].max()
ind=df[df['mean_salary']==highest].index.values
print("Highest average salary is",highest,"and the area is",df['area'].iloc[ind].squeeze())

#to find lowest average salary and it's area
lowest=df['mean_salary'].min()
ind=df[df['mean_salary']==lowest].index.values
print("\nLowest average salary is",lowest,"and the area is",df['area'].iloc[ind].squeeze())
# Out:
# Highest average salary is 90842 and the area is city of london
#
# Lowest average salary is # and the area is 62       hackney
# 64      haringey
# 113      hackney
# 362      bromley
# 874      croydon
# 992       merton
# 1043      merton
# Name: area, dtype: object

# %% [markdown]
# **Print areas grouped by number of recycling projects**

# %%
import pandas as pd

url="https://raw.githubusercontent.com/futureCodersSE/working-with-data/main/Data%20sets/housing_in_london_yearly_variables.csv"
df=pd.read_csv(url)

for i in df['recycling_pct'].unique():
  df1=df.loc[df['recycling_pct']==i]
  print("\n",i)

  for j in df1['area'].unique():
    print(j)
# Out:
#  0
# city of london
#
#  3
# barking and dagenham
# newham
# southwark
# tower hamlets
# hackney
#
#  8
# barnet
# havering
# lambeth
# redbridge
# enfield
# hammersmith and fulham
# kensington and chelsea
# north west
# waltham forest
# wandsworth
# brent
# city of london
# lewisham
#
#  18
# bexley
# kingston upon thames
# merton
# south east
# wandsworth
# england
# kensington and chelsea
# waltham forest
# london
# city of london
# havering
# islington
# westminster
# southwark
# lewisham
# newham
#
#  6
# brent
# havering
# islington
# lewisham
# hackney
# newham
#
#  13
# bromley
# camden
# croydon
# kensington and chelsea
# hillingdon
# hounslow
# east midlands
# ealing
# enfield
# harrow
# england
# barnet
# redbridge
# west midlands
# london
# tower hamlets
#
#  12
# ealing
# croydon
# camden
# harrow
# greenwich
# lambeth
# waltham forest
# north east
# hackney
# lewisham
# tower hamlets
#
#  9
# enfield
# waltham forest
# west midlands
# london
# lambeth
# redbridge
# ...
